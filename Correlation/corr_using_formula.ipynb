# %%
import pandas as pd
import math
age=[15,26,10,9,15,20,18,11,8,20]
score=[97,73,85,93,104,89,95,102,106,96]

def mean(x):
    sum = 0.0
    for i in x:
         sum += i
    return float(sum / len(x)) 

#sd(x)=sqrt( (xi-mean(x))^2 / n-1 )
def standardDeviation(x):
    sum_sd = 0.0
    for i in x:
         sum_sd += (i - mean(x))**2
    return math.sqrt(sum_sd/(len(x)-1))

#covariance(x,y)=sum(xi-mean(x)* yi-mean(y))/ n-1
def covariance(x,y):
    cov_xy = []
    for i,j in zip(x,y):
        x1 = i-mean(x)
        y1 = j-mean(y)
        cov_xy.append(x1*y1)
    cov = sum(cov_xy)   
    return cov/(len(x)-1)

#correlation(x,y)=covariance(x,y)/sd(x)*sd(y)
def correlation(x, y):
    corr = (covariance(x,y)) / (standardDeviation(x)*standardDeviation(y))
    return corr
        
print ("Predicting_mental_ability(age vs score)")
print("\nmean_age:",mean(age))
print("mean_score:",mean(score))
print("\nsd (age) :",standardDeviation(age))
print("sd (score) :",standardDeviation(score))
print("\ncovariance (age,score):",covariance(age,score))
print("\nCorrelation , r : ",correlation(age,score))
# Out:
# Predicting_mental_ability(age vs score)
#
# mean_age: 15.2
# mean_score: 94.0
#
# sd (age) : 5.827139568909908
# sd (score) : 9.83192080250175
#
# covariance (age,score): -34.22222222222222
#
# Correlation , r :  -0.5973301212527226

# %%
import pandas as pd
import math
stumps=[2,2,1,3,4,1,5,3,1,2]
bl=[12,32,14,26,42,13,58,42,10,16]

def mean(x):
    sum = 0.0
    for i in x:
         sum += i
    return float(sum / len(x)) 

#sd(x)=sqrt( (xi-mean(x))^2 / n-1 )
def standardDeviation(x):
    sum_sd = 0.0
    for i in x:
         sum_sd += (i - mean(x))**2
    return math.sqrt(sum_sd/(len(x)-1))

#covariance(x,y)=sum(xi-mean(x)* yi-mean(y))/ n-1
def covariance(x,y):
    cov_xy = []
    for i,j in zip(x,y):
        x1 = i-mean(x)
        y1 = j-mean(y)
        cov_xy.append(x1*y1)
    cov = sum(cov_xy)   
    return cov/(len(x)-1)

#correlation(x,y)=covariance(x,y)/sd(x)*sd(y)
def correlation(x, y):
    corr = (covariance(x,y)) / (standardDeviation(x)*standardDeviation(y))
    return corr
        
print ("\nTree stumps vs Beetle Larvae")
print("\nmean_stumps:",mean(stumps))
print("mean_beetlelarvae:",mean(bl))
print("\nsd (stumps) :",standardDeviation(stumps))
print("sd (beetlelarvae) :",standardDeviation(bl))
print("\ncovariance (stumps,beetlelarvae):",covariance(stumps,bl))
print("\nCorrelation , r : ",correlation(stumps,bl))
# Out:
# Tree stumps vs Beetle Larvae
#
# mean_stumps: 2.4
# mean_beetlelarvae: 26.5
#
# sd (stumps) : 1.349897115421106
# sd (beetlelarvae) : 16.446884203398525
#
# covariance (stumps,beetlelarvae): 20.333333333333332
#
# Correlation , r :  0.9158498450298386

# %%
import pandas as pd
import math
mphr=[20,30,40,50,60]
mpg=[26,30,32,30,26]

def mean(x):
    sum = 0.0
    for i in x:
         sum += i
    return float(sum / len(x)) 

#sd(x)=sqrt( (xi-mean(x))^2 / n-1 )
def standardDeviation(x):
    sum_sd = 0.0
    for i in x:
         sum_sd += (i - mean(x))**2
    return math.sqrt(sum_sd/(len(x)-1))

#covariance(x,y)=sum(xi-mean(x)* yi-mean(y))/ n-1
def covariance(x,y):
    cov_xy = []
    for i,j in zip(x,y):
        x1 = i-mean(x)
        y1 = j-mean(y)
        cov_xy.append(x1*y1)
    cov = sum(cov_xy)   
    return cov/(len(x)-1)

#correlation(x,y)=covariance(x,y)/sd(x)*sd(y)
def correlation(x, y):
    corr = (covariance(x,y)) / (standardDeviation(x)*standardDeviation(y))
    return corr
        
print ("Speed and gas mileage")
print("\nmean_miles/hr:",mean(mphr))
print("mean_miles/gal:",mean(mpg))
print("\nsd (miles/hr) :",standardDeviation(mphr))
print("sd (miles/gal) :",standardDeviation(mpg))
print("\ncovariance (miles/hr,miles/gal):",covariance(mphr,mpg))
print("\nCorrelation , r : ",correlation(mphr,mpg))
# Out:
# Speed and gas mileage
#
# mean_miles/hr: 40.0
# mean_miles/gal: 28.8
#
# sd (miles/hr) : 15.811388300841896
# sd (miles/gal) : 2.6832815729997477
#
# covariance (miles/hr,miles/gal): 0.0
#
# Correlation , r :  0.0

# %%
import pandas as pd
import math
from sklearn.datasets import load_iris

#Loading the iris dataset
data = load_iris()

#correlation between sepal_length and species
data1 = data.data[:,0].tolist()
data2 = data.target.tolist()

#correlation between petal_length and species
data3 = data.data[:,2].tolist()
data4 = data.target.tolist()

def mean(x):
    sum = 0.0
    for i in x:
         sum += i
    return float(sum / len(x)) 

#sd(x)=sqrt( (xi-mean(x))^2 / n-1 )
def standardDeviation(x):
    sum_sd = 0.0
    for i in x:
         sum_sd += (i - mean(x))**2
    return math.sqrt(sum_sd/(len(x)-1))

#covariance(x,y)=sum(xi-mean(x)* yi-mean(y))/ n-1
def covariance(x,y):
    cov_xy = []
    for i,j in zip(x,y):
        x1 = i-mean(x)
        y1 = j-mean(y)
        cov_xy.append(x1*y1)
    cov = sum(cov_xy)   
    return cov/(len(x)-1)

#correlation(x,y)=covariance(x,y)/sd(x)*sd(y)
def correlation(x, y):
    corr = (covariance(x,y)) / (standardDeviation(x)*standardDeviation(y))
    return corr
        
print ("correlation between sepal_length and species")
print("mean_sepal_length :",mean(data1))
print("mean_species:",mean(data2))
print("sd (sepal_length) :",standardDeviation(data1))
print("sd (species) :",standardDeviation(data2))
print("covariance (sepal_length,species):",covariance(data1,data2))
print("\nCorrelation , r : ",correlation(data1,data2))

print ("\ncorrelation between petal_length and species")
print("mean_petal_length :",mean(data3))
print("mean_species:",mean(data4))
print("sd (petal_length) :",standardDeviation(data3))
print("sd (species) :",standardDeviation(data4))
print("covariance (petal_length,species):",covariance(data3,data4))
print("\nCorrelation , r : ",correlation(data3,data4))
# Out:
# correlation between sepal_length and species
# mean_sepal_length : 5.843333333333335
# mean_species: 1.0
# sd (sepal_length) : 0.8280661279778629
# sd (species) : 0.8192319205190405
# covariance (sepal_length,species): 0.530872483221477
#
# Correlation , r :  0.7825612318100821
#
# correlation between petal_length and species
# mean_petal_length : 3.7580000000000027
# mean_species: 1.0
# sd (petal_length) : 1.7652982332594667
# sd (species) : 0.8192319205190405
# covariance (petal_length,species): 1.372483221476509
#
# Correlation , r :  0.9490346990083878
